# %% [markdown]
# ## Web scraping and analysis
#
# In this notebook, I'll scrape data from Skytrax's page with British Airways customer reviews using the `BeautifulSoup` package.
#
# Once the data has been collected, it will be saved to a `.csv` file.
#
# ### Scraping data from Skytrax
#
# The reviews are available at this link: [https://www.airlinequality.com/airline-reviews/british-airways]

# %% [markdown]
# # Importing relevant packages

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Web Scraping with `BeautifulSoup`
#
# The time period for the reviews retrieved is the period between 6th May 2014 and 9th January 2023.
#
# ---
# This code was last executed on 9th January, 2023.

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 344
page_size = 100

reviews = []

# for i in range(1, pages + 1):
for i in range(1, pages + 1):

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())
    
    print(f"   ---> {len(reviews)} total reviews")
# Out:
# Scraping page 1
#    ---> 100 total reviews
# Scraping page 2
#    ---> 200 total reviews
# Scraping page 3
#    ---> 300 total reviews
# Scraping page 4
#    ---> 400 total reviews
# Scraping page 5
#    ---> 500 total reviews
# Scraping page 6
#    ---> 600 total reviews
# Scraping page 7
#    ---> 700 total reviews
# Scraping page 8
#    ---> 800 total reviews
# Scraping page 9
#    ---> 900 total reviews
# Scraping page 10
#    ---> 1000 total reviews
# Scraping page 11
#    ---> 1100 total reviews
# Scraping page 12
#    ---> 1200 total reviews
# Scraping page 13
#    ---> 1300 total reviews
# Scraping page 14
#    ---> 1400 total reviews
# Scraping page 15
#    ---> 1500 total reviews
# Scraping page 16
#    ---> 1600 total reviews
# Scraping page 17
#    ---> 1700 total reviews
# Scraping page 18
#    ---> 1800 total reviews
# Scraping page 19
#    ---> 1900 total reviews
# Scraping page 20
#    ---> 2000 total reviews
# Scraping page 21
#    ---> 2100 total reviews
# Scraping page 22
#    ---> 2200 total reviews
# Scraping page 23
#    ---> 2300 total reviews
# Scraping page 24
#    ---> 2400 total reviews
# Scraping page 25
#    ---> 2500 total reviews
# Scraping page 26
#    ---> 2600 total reviews
# Scraping page 27
#    ---> 2700 total reviews
# Scraping page 28
#    ---> 2800 total reviews
# Scraping page 29
#    ---> 2900 total reviews
# Scraping page 30
#    ---> 3000 total reviews
# Scraping page 31
#    ---> 3100 total reviews
# Scraping page 32
#    ---> 3200 total reviews
# Scraping page 33
#    ---> 3300 total reviews
# Scraping page 34
#    ---> 3400 total reviews
# Scraping page 35
#    ---> 3453 total reviews
# Scraping page 36
#    ---> 3453 total reviews
# Scraping page 37
#    ---> 3453 total reviews
# Scraping page 38
#    ---> 3453 total reviews
# Scraping page 39
#    ---> 3453 total reviews
# Scraping page 40
#    ---> 3453 total reviews
# Scraping page 41
#    ---> 3453 total reviews
# Scraping page 42
#    ---> 3453 total reviews
# Scraping page 43
#    ---> 3453 total reviews
# Scraping page 44
#    ---> 3453 total reviews
# Scraping page 45
#    ---> 3453 total reviews
# Scraping page 46
#    ---> 3453 total reviews
# Scraping page 47
#    ---> 3453 total reviews
# Scraping page 48
#    ---> 3453 total reviews
# Scraping page 49
#    ---> 3453 total reviews
# Scraping page 50
#    ---> 3453 total reviews
# Scraping page 51
#    ---> 3453 total reviews
# Scraping page 52
#    ---> 3453 total reviews
# Scraping page 53
#    ---> 3453 total reviews
# Scraping page 54
#    ---> 3453 total reviews
# Scraping page 55
#    ---> 3453 total reviews
# Scraping page 56
#    ---> 3453 total reviews
# Scraping page 57
#    ---> 3453 total reviews
# Scraping page 58
#    ---> 3453 total reviews
# Scraping page 59
#    ---> 3453 total reviews
# Scraping page 60
#    ---> 3453 total reviews
# Scraping page 61
#    ---> 3453 total reviews
# Scraping page 62
#    ---> 3453 total reviews
# Scraping page 63
#    ---> 3453 total reviews
# Scraping page 64
#    ---> 3453 total reviews
# Scraping page 65
#    ---> 3453 total reviews
# Scraping page 66
#    ---> 3453 total reviews
# Scraping page 67
#    ---> 3453 total reviews
# Scraping page 68
#    ---> 3453 total reviews
# Scraping page 69
#    ---> 3453 total reviews
# Scraping page 70
#    ---> 3453 total reviews
# Scraping page 71
#    ---> 3453 total reviews
# Scraping page 72
#    ---> 3453 total reviews
# Scraping page 73
#    ---> 3453 total reviews
# Scraping page 74
#    ---> 3453 total reviews
# Scraping page 75
#    ---> 3453 total reviews
# Scraping page 76
#    ---> 3453 total reviews
# Scraping page 77
#    ---> 3453 total reviews
# Scraping page 78
#    ---> 3453 total reviews
# Scraping page 79
#    ---> 3453 total reviews
# Scraping page 80
#    ---> 3453 total reviews
# Scraping page 81
#    ---> 3453 total reviews
# Scraping page 82
#    ---> 3453 total reviews
# Scraping page 83
#    ---> 3453 total reviews
# Scraping page 84
#    ---> 3453 total reviews
# Scraping page 85
#    ---> 3453 total reviews
# Scraping page 86
#    ---> 3453 total reviews
# Scraping page 87
#    ---> 3453 total reviews
# Scraping page 88
#    ---> 3453 total reviews
# Scraping page 89
#    ---> 3453 total reviews
# Scraping page 90
#    ---> 3453 total reviews
# Scraping page 91
#    ---> 3453 total reviews
# Scraping page 92
#    ---> 3453 total reviews
# Scraping page 93
#    ---> 3453 total reviews
# Scraping page 94
#    ---> 3453 total reviews
# Scraping page 95
#    ---> 3453 total reviews
# Scraping page 96
#    ---> 3453 total reviews
# Scraping page 97
#    ---> 3453 total reviews
# Scraping page 98
#    ---> 3453 total reviews
# Scraping page 99
#    ---> 3453 total reviews
# Scraping page 100
#    ---> 3453 total reviews
# Scraping page 101
#    ---> 3453 total reviews
# Scraping page 102
#    ---> 3453 total reviews
# Scraping page 103
#    ---> 3453 total reviews
# Scraping page 104
#    ---> 3453 total reviews
# Scraping page 105
#    ---> 3453 total reviews
# Scraping page 106
#    ---> 3453 total reviews
# Scraping page 107
#    ---> 3453 total reviews
# Scraping page 108
#    ---> 3453 total reviews
# Scraping page 109
#    ---> 3453 total reviews
# Scraping page 110
#    ---> 3453 total reviews
# Scraping page 111
#    ---> 3453 total reviews
# Scraping page 112
#    ---> 3453 total reviews
# Scraping page 113
#    ---> 3453 total reviews
# Scraping page 114
#    ---> 3453 total reviews
# Scraping page 115
#    ---> 3453 total reviews
# Scraping page 116
#    ---> 3453 total reviews
# Scraping page 117
#    ---> 3453 total reviews
# Scraping page 118
#    ---> 3453 total reviews
# Scraping page 119
#    ---> 3453 total reviews
# Scraping page 120
#    ---> 3453 total reviews
# Scraping page 121
#    ---> 3453 total reviews
# Scraping page 122
#    ---> 3453 total reviews
# Scraping page 123
#    ---> 3453 total reviews
# Scraping page 124
#    ---> 3453 total reviews
# Scraping page 125
#    ---> 3453 total reviews
# Scraping page 126
#    ---> 3453 total reviews
# Scraping page 127
#    ---> 3453 total reviews
# Scraping page 128
#    ---> 3453 total reviews
# Scraping page 129
#    ---> 3453 total reviews
# Scraping page 130
#    ---> 3453 total reviews
# Scraping page 131
#    ---> 3453 total reviews
# Scraping page 132
#    ---> 3453 total reviews
# Scraping page 133
#    ---> 3453 total reviews
# Scraping page 134
#    ---> 3453 total reviews
# Scraping page 135
#    ---> 3453 total reviews
# Scraping page 136
#    ---> 3453 total reviews
# Scraping page 137
#    ---> 3453 total reviews
# Scraping page 138
#    ---> 3453 total reviews
# Scraping page 139
#    ---> 3453 total reviews
# Scraping page 140
#    ---> 3453 total reviews
# Scraping page 141
#    ---> 3453 total reviews
# Scraping page 142
#    ---> 3453 total reviews
# Scraping page 143
#    ---> 3453 total reviews
# Scraping page 144
#    ---> 3453 total reviews
# Scraping page 145
#    ---> 3453 total reviews
# Scraping page 146
#    ---> 3453 total reviews
# Scraping page 147
#    ---> 3453 total reviews
# Scraping page 148
#    ---> 3453 total reviews
# Scraping page 149
#    ---> 3453 total reviews
# Scraping page 150
#    ---> 3453 total reviews
# Scraping page 151
#    ---> 3453 total reviews
# Scraping page 152
#    ---> 3453 total reviews
# Scraping page 153
#    ---> 3453 total reviews
# Scraping page 154
#    ---> 3453 total reviews
# Scraping page 155
#    ---> 3453 total reviews
# Scraping page 156
#    ---> 3453 total reviews
# Scraping page 157
#    ---> 3453 total reviews
# Scraping page 158
#    ---> 3453 total reviews
# Scraping page 159
#    ---> 3453 total reviews
# Scraping page 160
#    ---> 3453 total reviews
# Scraping page 161
#    ---> 3453 total reviews
# Scraping page 162
#    ---> 3453 total reviews
# Scraping page 163
#    ---> 3453 total reviews
# Scraping page 164
#    ---> 3453 total reviews
# Scraping page 165
#    ---> 3453 total reviews
# Scraping page 166
#    ---> 3453 total reviews
# Scraping page 167
#    ---> 3453 total reviews
# Scraping page 168
#    ---> 3453 total reviews
# Scraping page 169
#    ---> 3453 total reviews
# Scraping page 170
#    ---> 3453 total reviews
# Scraping page 171
#    ---> 3453 total reviews
# Scraping page 172
#    ---> 3453 total reviews
# Scraping page 173
#    ---> 3453 total reviews
# Scraping page 174
#    ---> 3453 total reviews
# Scraping page 175
#    ---> 3453 total reviews
# Scraping page 176
#    ---> 3453 total reviews
# Scraping page 177
#    ---> 3453 total reviews
# Scraping page 178
#    ---> 3453 total reviews
# Scraping page 179
#    ---> 3453 total reviews
# Scraping page 180
#    ---> 3453 total reviews
# Scraping page 181
#    ---> 3453 total reviews
# Scraping page 182
#    ---> 3453 total reviews
# Scraping page 183
#    ---> 3453 total reviews
# Scraping page 184
#    ---> 3453 total reviews
# Scraping page 185
#    ---> 3453 total reviews
# Scraping page 186
#    ---> 3453 total reviews
# Scraping page 187
#    ---> 3453 total reviews
# Scraping page 188
#    ---> 3453 total reviews
# Scraping page 189
#    ---> 3453 total reviews
# Scraping page 190
#    ---> 3453 total reviews
# Scraping page 191
#    ---> 3453 total reviews
# Scraping page 192
#    ---> 3453 total reviews
# Scraping page 193
#    ---> 3453 total reviews
# Scraping page 194
#    ---> 3453 total reviews
# Scraping page 195
#    ---> 3453 total reviews
# Scraping page 196
#    ---> 3453 total reviews
# Scraping page 197
#    ---> 3453 total reviews
# Scraping page 198
#    ---> 3453 total reviews
# Scraping page 199
#    ---> 3453 total reviews
# Scraping page 200
#    ---> 3453 total reviews
# Scraping page 201
#    ---> 3453 total reviews
# Scraping page 202
#    ---> 3453 total reviews
# Scraping page 203
#    ---> 3453 total reviews
# Scraping page 204
#    ---> 3453 total reviews
# Scraping page 205
#    ---> 3453 total reviews
# Scraping page 206
#    ---> 3453 total reviews
# Scraping page 207
#    ---> 3453 total reviews
# Scraping page 208
#    ---> 3453 total reviews
# Scraping page 209
#    ---> 3453 total reviews
# Scraping page 210
#    ---> 3453 total reviews
# Scraping page 211
#    ---> 3453 total reviews
# Scraping page 212
#    ---> 3453 total reviews
# Scraping page 213
#    ---> 3453 total reviews
# Scraping page 214
#    ---> 3453 total reviews
# Scraping page 215
#    ---> 3453 total reviews
# Scraping page 216
#    ---> 3453 total reviews
# Scraping page 217
#    ---> 3453 total reviews
# Scraping page 218
#    ---> 3453 total reviews
# Scraping page 219
#    ---> 3453 total reviews
# Scraping page 220
#    ---> 3453 total reviews
# Scraping page 221
#    ---> 3453 total reviews
# Scraping page 222
#    ---> 3453 total reviews
# Scraping page 223
#    ---> 3453 total reviews
# Scraping page 224
#    ---> 3453 total reviews
# Scraping page 225
#    ---> 3453 total reviews
# Scraping page 226
#    ---> 3453 total reviews
# Scraping page 227
#    ---> 3453 total reviews
# Scraping page 228
#    ---> 3453 total reviews
# Scraping page 229
#    ---> 3453 total reviews
# Scraping page 230
#    ---> 3453 total reviews
# Scraping page 231
#    ---> 3453 total reviews
# Scraping page 232
#    ---> 3453 total reviews
# Scraping page 233
#    ---> 3453 total reviews
# Scraping page 234
#    ---> 3453 total reviews
# Scraping page 235
#    ---> 3453 total reviews
# Scraping page 236
#    ---> 3453 total reviews
# Scraping page 237
#    ---> 3453 total reviews
# Scraping page 238
#    ---> 3453 total reviews
# Scraping page 239
#    ---> 3453 total reviews
# Scraping page 240
#    ---> 3453 total reviews
# Scraping page 241
#    ---> 3453 total reviews
# Scraping page 242
#    ---> 3453 total reviews
# Scraping page 243
#    ---> 3453 total reviews
# Scraping page 244
#    ---> 3453 total reviews
# Scraping page 245
#    ---> 3453 total reviews
# Scraping page 246
#    ---> 3453 total reviews
# Scraping page 247
#    ---> 3453 total reviews
# Scraping page 248
#    ---> 3453 total reviews
# Scraping page 249
#    ---> 3453 total reviews
# Scraping page 250
#    ---> 3453 total reviews
# Scraping page 251
#    ---> 3453 total reviews
# Scraping page 252
#    ---> 3453 total reviews
# Scraping page 253
#    ---> 3453 total reviews
# Scraping page 254
#    ---> 3453 total reviews
# Scraping page 255
#    ---> 3453 total reviews
# Scraping page 256
#    ---> 3453 total reviews
# Scraping page 257
#    ---> 3453 total reviews
# Scraping page 258
#    ---> 3453 total reviews
# Scraping page 259
#    ---> 3453 total reviews
# Scraping page 260
#    ---> 3453 total reviews
# Scraping page 261
#    ---> 3453 total reviews
# Scraping page 262
#    ---> 3453 total reviews
# Scraping page 263
#    ---> 3453 total reviews
# Scraping page 264
#    ---> 3453 total reviews
# Scraping page 265
#    ---> 3453 total reviews
# Scraping page 266
#    ---> 3453 total reviews
# Scraping page 267
#    ---> 3453 total reviews
# Scraping page 268
#    ---> 3453 total reviews
# Scraping page 269
#    ---> 3453 total reviews
# Scraping page 270
#    ---> 3453 total reviews
# Scraping page 271
#    ---> 3453 total reviews
# Scraping page 272
#    ---> 3453 total reviews
# Scraping page 273
#    ---> 3453 total reviews
# Scraping page 274
#    ---> 3453 total reviews
# Scraping page 275
#    ---> 3453 total reviews
# Scraping page 276
#    ---> 3453 total reviews
# Scraping page 277
#    ---> 3453 total reviews
# Scraping page 278
#    ---> 3453 total reviews
# Scraping page 279
#    ---> 3453 total reviews
# Scraping page 280
#    ---> 3453 total reviews
# Scraping page 281
#    ---> 3453 total reviews
# Scraping page 282
#    ---> 3453 total reviews
# Scraping page 283
#    ---> 3453 total reviews
# Scraping page 284
#    ---> 3453 total reviews
# Scraping page 285
#    ---> 3453 total reviews
# Scraping page 286
#    ---> 3453 total reviews
# Scraping page 287
#    ---> 3453 total reviews
# Scraping page 288
#    ---> 3453 total reviews
# Scraping page 289
#    ---> 3453 total reviews
# Scraping page 290
#    ---> 3453 total reviews
# Scraping page 291
#    ---> 3453 total reviews
# Scraping page 292
#    ---> 3453 total reviews
# Scraping page 293
#    ---> 3453 total reviews
# Scraping page 294
#    ---> 3453 total reviews
# Scraping page 295
#    ---> 3453 total reviews
# Scraping page 296
#    ---> 3453 total reviews
# Scraping page 297
#    ---> 3453 total reviews
# Scraping page 298
#    ---> 3453 total reviews
# Scraping page 299
#    ---> 3453 total reviews
# Scraping page 300
#    ---> 3453 total reviews
# Scraping page 301
#    ---> 3453 total reviews
# Scraping page 302
#    ---> 3453 total reviews
# Scraping page 303
#    ---> 3453 total reviews
# Scraping page 304
#    ---> 3453 total reviews
# Scraping page 305
#    ---> 3453 total reviews
# Scraping page 306
#    ---> 3453 total reviews
# Scraping page 307
#    ---> 3453 total reviews
# Scraping page 308
#    ---> 3453 total reviews
# Scraping page 309
#    ---> 3453 total reviews
# Scraping page 310
#    ---> 3453 total reviews
# Scraping page 311
#    ---> 3453 total reviews
# Scraping page 312
#    ---> 3453 total reviews
# Scraping page 313
#    ---> 3453 total reviews
# Scraping page 314
#    ---> 3453 total reviews
# Scraping page 315
#    ---> 3453 total reviews
# Scraping page 316
#    ---> 3453 total reviews
# Scraping page 317
#    ---> 3453 total reviews
# Scraping page 318
#    ---> 3453 total reviews
# Scraping page 319
#    ---> 3453 total reviews
# Scraping page 320
#    ---> 3453 total reviews
# Scraping page 321
#    ---> 3453 total reviews
# Scraping page 322
#    ---> 3453 total reviews
# Scraping page 323
#    ---> 3453 total reviews
# Scraping page 324
#    ---> 3453 total reviews
# Scraping page 325
#    ---> 3453 total reviews
# Scraping page 326
#    ---> 3453 total reviews
# Scraping page 327
#    ---> 3453 total reviews
# Scraping page 328
#    ---> 3453 total reviews
# Scraping page 329
#    ---> 3453 total reviews
# Scraping page 330
#    ---> 3453 total reviews
# Scraping page 331
#    ---> 3453 total reviews
# Scraping page 332
#    ---> 3453 total reviews
# Scraping page 333
#    ---> 3453 total reviews
# Scraping page 334
#    ---> 3453 total reviews
# Scraping page 335
#    ---> 3453 total reviews
# Scraping page 336
#    ---> 3453 total reviews
# Scraping page 337
#    ---> 3453 total reviews
# Scraping page 338
#    ---> 3453 total reviews
# Scraping page 339
#    ---> 3453 total reviews
# Scraping page 340
#    ---> 3453 total reviews
# Scraping page 341
#    ---> 3453 total reviews
# Scraping page 342
#    ---> 3453 total reviews
# Scraping page 343
#    ---> 3453 total reviews
# Scraping page 344
#    ---> 3453 total reviews

# %%
df = pd.DataFrame()
df["reviews"] = reviews
df.head(20)
# Out:
#                                               reviews
# 0   Not Verified |  Great thing about British Airw...
# 1   Not Verified | The staff are friendly. The pla...
# 2   ✅ Trip Verified | Probably the worst business ...
# 3   ✅ Trip Verified | Definitely not recommended, ...
# 4   ✅ Trip Verified |  BA shuttle service across t...
# 5   ✅ Trip Verified | I must admit like many other...
# 6   Not Verified |  When will BA update their Busi...
# 7   ✅ Trip Verified |  Paid £200 day before flight...
# 8   ✅ Trip Verified |  BA website did not work (we...
# 9   ✅ Trip Verified |  Absolutely terrible experie...
# 10  ✅ Trip Verified |  Vancouver to Delhi via Lond...
# 11  ✅ Trip Verified |  Old A320 with narrow pitch....
# 12  ✅ Trip Verified |  Another BA Shambles. Starte...
# 13  Not Verified |  BA cancelled my flight home to...
# 14  Not Verified |  BA cancelled my flight home, t...
# 15  ✅ Trip Verified | Turned up 3.5 hours in advan...
# 16  Not Verified |  Boarding – at gate at LGW they...
# 17  ✅ Trip Verified |  Missing baggage customer se...
# 18  ✅ Trip Verified |  British Airways are not the...
# 19  ✅ Trip Verified |  Stupidly tried BA again aft...

# %%
df.tail(20)
# Out:
#                                                 reviews
# 3433  Chicago O'Hare to London Heathrow on 2 May. ch...
# 3434  Travelled to HKG on board the new A380. Boardi...
# 3435  BA 059 London to Cape Town April 29 2014 econo...
# 3436  Las Vegas-LGW 777 3 class. Business. The uniqu...
# 3437  An interesting contrast on recent Gatwick to T...
# 3438  Heathrow Marrakech. Had previously travelled o...
# 3439  Just got back from Bridgetown Barbados flying ...
# 3440  LHR-JFK-LAX-LHR. Check in was ok apart from be...
# 3441  HKG-LHR in New Club World on Boeing 777-300 - ...
# 3442  YYZ to LHR - July 2012 - I flew overnight in p...
# 3443  Flew return in CW from LHR to BKK in August 20...
# 3444  Flew LHR - VIE return operated by bmi but BA a...
# 3445  Flight from Heathrow to Toronto. Booked emerge...
# 3446  Business LHR to BKK. 747-400. First try back w...
# 3447  This was a bmi Regional operated flight on a R...
# 3448  LHR-HKG on Boeing 747 - 23/08/12. Much has bee...
# 3449  LHR to HAM. Purser addresses all club passenge...
# 3450  My son who had worked for British Airways urge...
# 3451  London City-New York JFK via Shannon on A318 b...
# 3452  SIN-LHR BA12 B747-436 First Class. Old aircraf...

# %% [markdown]
# Saving to `.csv` file to continue analysis in another notebook

# %%
df.to_csv("/content/drive/MyDrive/BA/data/BA_reviews.csv")
